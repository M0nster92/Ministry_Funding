# %%
import pandas as pd

# %%
df = pd.read_csv("api_fundingss.csv")

# %%
df.head()
# Out:
#    id                                         title  status  \
# 0   1  Advanced exploration and development support       1
# 1   2                     Early exploration support       1
# 2   3           Education and relationship-building       1
# 3   4            Mineral development advisor stream       1
# 4   5           Values mapping and related projects       1
#
#                                          deadline  \
# 0  Applications are accepted on an ongoing basis.
# 1  Applications are accepted on an ongoing basis.
# 2  Applications are accepted on an ongoing basis.
# 3  Applications are accepted on an ongoing basis.
# 4  Applications are accepted on an ongoing basis.
#
#                                          eligibility  \
# 0  Funding is available to Indigenous communities...
# 1  Funding is available to Indigenous communities...
# 2  Project funding is open to Indigenous communit...
# 3  Funding is available to Ontario Aboriginal com...
# ...

# %%
ministry_status = df.groupby("ministry_id")["status"].sum().sort_values()

# %%
ministry_status
# Out:
# ministry_id
# Ministry for Seniors and Accessibility\n                                     1
# Ministry of Francophone Affairs\n                                            1
# Ministry of Labour, Training and Skills Development\n                        1
# Ministry of Heritage, Sport, Tourism and Culture Industries\n                2
# Ministry of Indigenous Affairs\n                                             2
# Ministry of Transportation\n                                                 2
# Ministry of Economic Development, Job Creation and Trade\n                   3
# Ministry of Northern Development, Mines, Natural Resources and Forestry\n    4
# Ministry of Energy, Northern Development and Mines\n                         5
# Ministry of Children, Community and Social Services\n                        6
# Name: status, dtype: int64

# %%
ministry_status.plot(kind="barh")

# %%
ministry_status.plot(kind="pie")
